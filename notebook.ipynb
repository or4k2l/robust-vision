# %% [markdown]
# # Physically-Inspired Pattern Matching
#
# Minimal Colab notebook to run the benchmarks.

# %% [markdown]
# ## Setup
# Clone the repository and install dependencies.

# %%
# !git clone https://github.com/or4k2l/physical-pattern-matching.git
# %cd physical-pattern-matching
# !pip install -r requirements.txt

# %% [markdown]
# ## Run
# Execute the basic benchmark script.

# %%
# !python physically_inspired_pattern_matching.py
